# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
marathon_df = pd.read_csv("../Data/Riyadh Marathon Results.csv")

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
marathon_df.head()
# Out:
#    Unnamed: 0       Rank Gender Rank                                  Name  \
# 0           0  46 / 2285     1 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 1           1  53 / 2285     2 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 2           2  55 / 2285     3 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 3           3  88 / 2285     4 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 4           4  93 / 2285     5 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
#
#    Gender  Category         Nationality      Gun Time     Chip Time  \
# 0  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556  00:42:57.505
# 1  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175  00:43:24.774
# 2  Female  10KM RUN  [img:flags/SA.gif]  00:44:00.251  00:43:56.317
# 3  Female  10KM RUN  [img:flags/MA.gif]  00:48:28.115  00:48:22.908
# 4  Female  10KM RUN  [img:flags/SA.gif]  00:58:37.753  00:48:27.714
#
#         Speed         Pace Distance
# 0  13.9 Km/Hr  4:17 min/km    10 KM
# 1  13.8 Km/Hr  4:20 min/km    10 KM
# 2  13.6 Km/Hr  4:23 min/km    10 KM
# 3  12.4 Km/Hr  4:50 min/km    10 KM
# 4  12.3 Km/Hr  4:50 min/km    10 KM

# %% [markdown]
# **Note:**
# - Your gun/clock time is the time on the official race clock from the moment the race started (when the gun went off) to when you crossed over the finish line.
# - Your net/chip time is the time from when you personally cross the starting line to when you cross the finish.

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
marathon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6397 entries, 0 to 6396
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   6397 non-null   int64
#  1   Rank         6397 non-null   object
#  2   Gender Rank  6397 non-null   object
#  3   Name         6397 non-null   object
#  4   Gender       6397 non-null   object
#  5   Category     6397 non-null   object
#  6   Nationality  6085 non-null   object
#  7   Gun Time     6397 non-null   object
#  8   Chip Time    6227 non-null   object
#  9   Speed        6227 non-null   object
#  10  Pace         6227 non-null   object
#  11  Distance     6397 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 599.8+ KB

# %%
marathon_df.shape
# Out:
# (6397, 12)

# %%
marathon_df.describe()
# Out:
#         Unnamed: 0
# count  6397.000000
# mean    537.356886
# std     381.548171
# min       0.000000
# 25%     213.000000
# 50%     477.000000
# 75%     797.000000
# max    1578.000000

# %%
marathon_df.columns
# Out:
# Index(['Unnamed: 0', 'Rank', 'Gender Rank', 'Name', 'Gender', 'Category',
#        'Nationality', 'Gun Time', 'Chip Time', 'Speed', 'Pace', 'Distance'],
#       dtype='object')

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ![image.png](attachment:89b2c150-e44d-4c6e-a51b-9214df98aaf1.png)

# %%
marathon_df.head()
# Out:
#    Unnamed: 0       Rank Gender Rank                                  Name  \
# 0           0  46 / 2285     1 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 1           1  53 / 2285     2 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 2           2  55 / 2285     3 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 3           3  88 / 2285     4 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 4           4  93 / 2285     5 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
#
#    Gender  Category         Nationality      Gun Time     Chip Time  \
# 0  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556  00:42:57.505
# 1  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175  00:43:24.774
# 2  Female  10KM RUN  [img:flags/SA.gif]  00:44:00.251  00:43:56.317
# 3  Female  10KM RUN  [img:flags/MA.gif]  00:48:28.115  00:48:22.908
# 4  Female  10KM RUN  [img:flags/SA.gif]  00:58:37.753  00:48:27.714
#
#         Speed         Pace Distance
# 0  13.9 Km/Hr  4:17 min/km    10 KM
# 1  13.8 Km/Hr  4:20 min/km    10 KM
# 2  13.6 Km/Hr  4:23 min/km    10 KM
# 3  12.4 Km/Hr  4:50 min/km    10 KM
# 4  12.3 Km/Hr  4:50 min/km    10 KM

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# in the kaggle page mentioned data source

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# check one of the files and the big file

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
marathon_df.head(10)
# Out:
#    Unnamed: 0        Rank Gender Rank                                  Name  \
# 0           0   46 / 2285     1 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 1           1   53 / 2285     2 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 2           2   55 / 2285     3 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 3           3   88 / 2285     4 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 4           4   93 / 2285     5 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 5           5  116 / 2285     6 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 6           6  130 / 2285     7 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 7           7  135 / 2285     8 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 8           8  148 / 2285     9 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
# 9           9  161 / 2285    10 / 761  6b848725-e44d-42d8-a278-ae67faa9cb80
#
#    Gender  Category         Nationality      Gun Time     Chip Time  \
# 0  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556  00:42:57.505
# 1  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175  00:43:24.774
# 2  Female  10KM RUN  [img:flags/SA.gif]  00:44:00.251  00:43:56.317
# 3  Female  10KM RUN  [img:flags/MA.gif]  00:48:28.115  00:48:22.908
# 4  Female  10KM RUN  [img:flags/SA.gif]  00:58:37.753  00:48:27.714
# 5  Female  10KM RUN  [img:flags/GB.gif]  00:58:35.135  00:49:58.260
# 6  Female  10KM RUN                 NaN  00:51:21.156  00:51:09.616
# 7  Female  10KM RUN  [img:flags/CN.gif]  00:53:20.321  00:51:24.245
# 8  Female  10KM RUN  [img:flags/BH.gif]  00:54:16.831  00:52:06.101
# 9  Female  10KM RUN  [img:flags/FR.gif]  00:54:20.530  00:52:47.669
#
#         Speed         Pace Distance
# 0  13.9 Km/Hr  4:17 min/km    10 KM
# 1  13.8 Km/Hr  4:20 min/km    10 KM
# 2  13.6 Km/Hr  4:23 min/km    10 KM
# 3  12.4 Km/Hr  4:50 min/km    10 KM
# 4  12.3 Km/Hr  4:50 min/km    10 KM
# 5  12.0 Km/Hr  4:59 min/km    10 KM
# 6  11.7 Km/Hr  5:06 min/km    10 KM
# 7  11.6 Km/Hr  5:08 min/km    10 KM
# 8  11.5 Km/Hr  5:12 min/km    10 KM
# 9  11.3 Km/Hr  5:16 min/km    10 KM

# %%
marathon_df[["Category", "Distance"]].value_counts()
# Out:
# Category             Distance
# 10KM RUN             10 KM       2352
# 4KM FUN RUN          4 KM        2225
# HALF MARATHON        21.1 KM     1152
# MARATHON             42.2 KM      474
#                      35 KM         53
# 4KM FUN RUN          0 KM          46
# MARATHON ELITE       42.2 KM       18
# 10KM RUN             0 KM          16
# MARATHON             20 KM          8
# HALF MARATHON        10 KM          7
# 10KM RUN             5 KM           6
# HALF MARATHON        20 KM          6
# HALF MARATHON ELITE  21.1 KM        6
# MARATHON             30 KM          5
# HALF MARATHON        15 KM          4
# MARATHON             0 KM           4
#                      25 KM          3
# HALF MARATHON        5 KM           2
# MARATHON             40 KM          2
#                      15 KM          2
#                      10 KM          1
#                      5 KM           1
# MARATHON ELITE       0 KM           1
#                      30 KM          1
#                      35 KM          1
#                      40 KM          1
# Name: count, dtype: int64

# %%
marathon_df["Name"].unique()
# Out:
# array(['6b848725-e44d-42d8-a278-ae67faa9cb80',
#        '6e60b635-494b-4bbd-9a92-bb52ae2bf140',
#        'ee2e687b-c339-4f3f-a481-2bee50f01521',
#        'e084862c-4867-4cec-85d1-cc9d2e8acb60',
#        '1bc14a33-5d72-4b18-a492-1d94d0eba76d',
#        '3ce2e755-b5ea-409a-9174-31778c11fcf0',
#        '7968347b-c3ac-417c-bccd-99854e8bf972',
#        '110903c1-ce66-4b6c-b35f-bfc2ed3fdb23',
#        'a4d8a45d-d0f0-4d00-8bc9-3d9d6e31f73d',
#        'ee5b6325-c4f3-4122-8247-1818e59912c2',
#        'cde359f8-5d73-4426-8ba6-cf021cfddbfc',
#        '7aa1ce03-6d9c-4b53-93a9-d01b1bae7334'], dtype=object)

# %%
#Delete unrelevent columns
marathon_df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
marathon_df.drop(["Name"],axis=1,inplace=True)

# %%
marathon_df.head()
# Out:
#         Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 0  46 / 2285     1 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556
# 1  53 / 2285     2 / 761  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175
# 2  55 / 2285     3 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:44:00.251
# 3  88 / 2285     4 / 761  Female  10KM RUN  [img:flags/MA.gif]  00:48:28.115
# 4  93 / 2285     5 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:58:37.753
#
#       Chip Time       Speed         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM
# 2  00:43:56.317  13.6 Km/Hr  4:23 min/km    10 KM
# 3  00:48:22.908  12.4 Km/Hr  4:50 min/km    10 KM
# 4  00:48:27.714  12.3 Km/Hr  4:50 min/km    10 KM

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
marathon_df.duplicated().sum() # -> 32020 duplicated rows
# Out:
# 94

# %%
#marathon_df[marathon_df.duplicated()][["Rank", "Gender Rank"]].value_counts()
marathon_df[marathon_df.duplicated()]
# Out:
#      Rank Gender Rank  Gender  Category         Nationality  \
# 767     -           -  Female  10KM RUN  [img:flags/SA.gif]
# 768     -           -  Female  10KM RUN  [img:flags/SA.gif]
# 769     -           -  Female  10KM RUN  [img:flags/SA.gif]
# 2321    -           -    Male  10KM RUN  [img:flags/PK.gif]
# 2322    -           -    Male  10KM RUN  [img:flags/SA.gif]
# ...   ...         ...     ...       ...                 ...
# 6274    -           -    Male  MARATHON  [img:flags/SA.gif]
# 6276    -           -    Male  MARATHON  [img:flags/SA.gif]
# 6278    -           -    Male  MARATHON  [img:flags/SA.gif]
# 6282    -           -    Male  MARATHON                 NaN
# 6284    -           -    Male  MARATHON  [img:flags/SA.gif]
#
#                   Gun Time Chip Time Speed Pace Distance
# 767   [32384.739|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 768   [32384.739|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 769   [32384.739|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 2321  [32384.739|hh:mm:ss]       NaN   NaN  NaN     5 KM
# 2322  [32384.739|hh:mm:ss]       NaN   NaN  NaN     5 KM
# ...                    ...       ...   ...  ...      ...
# 6274   [22526.31|hh:mm:ss]       NaN   NaN  NaN    20 KM
# 6276   [22526.31|hh:mm:ss]       NaN   NaN  NaN    20 KM
# 6278   [22526.31|hh:mm:ss]       NaN   NaN  NaN    15 KM
# 6282   [22526.31|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 6284   [22526.31|hh:mm:ss]       NaN   NaN  NaN     0 KM
#
# [94 rows x 10 columns]

# %%
marathon_df.drop_duplicates(inplace = True)

# %%
marathon_df.shape
# Out:
# (6303, 10)

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
#Display number missing values per column
marathon_df.isnull().sum().sort_values(ascending = False)
# Out:
# Nationality    306
# Chip Time       76
# Speed           76
# Pace            76
# Rank             0
# Gender Rank      0
# Gender           0
# Category         0
# Gun Time         0
# Distance         0
# dtype: int64

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
marathon_df.head(2)
# Out:
#         Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 0  46 / 2285     1 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556
# 1  53 / 2285     2 / 761  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175
#
#       Chip Time       Speed         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM

# %%
# check columns types 
marathon_df.dtypes
# Out:
# Rank           object
# Gender Rank    object
# Gender         object
# Category       object
# Nationality    object
# Gun Time       object
# Chip Time      object
# Speed          object
# Pace           object
# Distance       object
# dtype: object

# %%
# go to clean them

# %%
# check outliers 
marathon_df.head(2)
# Out:
#         Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 0  46 / 2285     1 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556
# 1  53 / 2285     2 / 761  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175
#
#       Chip Time       Speed         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
# [![](https://markdown-videos-api.jorgenkh.no/youtube/aUKfwkHfgiA)](https://www.youtube.com/watch?v=aUKfwkHfgiA)
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %%
# go to univariate graphical analysis
# go to lesson : data visualisation 1 - chart type section
# then go to univariate graphical analysis
# detect outliers using graphs varbaly

# %%
# go to lesson: statistics 1 then statistics 3
# then go to univariate Non graphical analysis
# detect outliers using numerical statistics

# %%
marathon_df.head(2)
# Out:
#         Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 0  46 / 2285     1 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556
# 1  53 / 2285     2 / 761  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175
#
#       Chip Time       Speed         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
speed_Q1 = marathon_df['Speed_Km/Hr'].quantile(0.25)
speed_Q3 = marathon_df['Speed_Km/Hr'].quantile(0.75)

# Calculate the IQR by subtracting Q1 from Q3
speed_IQR = speed_Q3 - speed_Q1

# Define the lower and upper bounds for the outliers
speed_lower_bound = speed_Q1 - 1.5 * speed_IQR
speed_upper_bound = speed_Q3 + 1.5 * speed_IQR

# # Filter out outliers
marathon_df[(marathon_df['Speed_Km/Hr'] < speed_lower_bound) | (marathon_df['Speed_Km/Hr'] > speed_upper_bound)]
# Out:
#       Rank  Gender Rank  Gender             Category Nationality  \
# 795      1            1    Male             10KM RUN          SA
# 796      2            2    Male             10KM RUN          SA
# 797      3            3    Male             10KM RUN          SO
# 798      4            4    Male             10KM RUN          SO
# 799      5            5    Male             10KM RUN          SA
# ...    ...          ...     ...                  ...         ...
# 6392     5            2  Female  HALF MARATHON ELITE          ET
# 6393     6            3  Female  HALF MARATHON ELITE          UA
# 6394     1            1    Male  HALF MARATHON ELITE          KE
# 6395     2            2    Male  HALF MARATHON ELITE          KE
# 6396     3            3    Male  HALF MARATHON ELITE          KE
#
#                    Gun Time              Chip Time  Speed_Km/Hr  Pace_min_Km  \
# 795  0 days 00:31:34.524000 0 days 00:31:33.764000         19.0         3.15
# 796  0 days 00:31:36.444000 0 days 00:31:35.168000         18.9         3.15
# 797  0 days 00:32:52.983000 0 days 00:32:52.381000         18.2         3.28
# 798  0 days 00:33:17.258000 0 days 00:33:15.920000         18.0         3.32
# 799  0 days 00:33:38.484000 0 days 00:33:36.183000         17.8         3.35
# ...                     ...                    ...          ...          ...
# 6392 0 days 01:12:12.475000 0 days 01:12:08.442000         17.5         3.42
# 6393 0 days 01:18:23.645000 0 days 01:18:20.056000         16.1         3.70
# 6394 0 days 01:04:04.250000 0 days 01:04:00.497000         19.7         3.03
# 6395 0 days 01:04:06.571000 0 days 01:04:03.202000         19.7         3.03
# 6396 0 days 01:04:09.986000 0 days 01:04:06.290000         19.7         3.03
#
#      Distance  Rank_Total  Gender_Rank_Total  Chip Time duration-min  \
# 795     10 KM        2285               1524                   31.56
# 796     10 KM        2285               1524                   31.59
# 797     10 KM        2285               1524                   32.87
# 798     10 KM        2285               1524                   33.27
# 799     10 KM        2285               1524                   33.60
# ...       ...         ...                ...                     ...
# 6392  21.1 KM           6                  3                   72.14
# 6393  21.1 KM           6                  3                   78.33
# 6394  21.1 KM           6                  3                   64.01
# 6395  21.1 KM           6                  3                   64.05
# 6396  21.1 KM           6                  3                   64.10
#
#       Gun Time duration-min
# 795                   31.58
# 796                   31.61
# 797                   32.88
# 798                   33.29
# 799                   33.64
# ...                     ...
# 6392                  72.21
# 6393                  78.39
# 6394                  64.07
# 6395                  64.11
# 6396                  64.17
#
# [140 rows x 14 columns]

# %%
# Calculate (5th percentile) and (95th percentile)
speed_5 = marathon_df['Speed_Km/Hr'].quantile(0.05)
speed_95 = marathon_df['Speed_Km/Hr'].quantile(0.95)

# Filter out outliers
marathon_df[(marathon_df['Speed_Km/Hr'] < speed_5) | (marathon_df['Speed_Km/Hr'] > speed_95)].shape

# %%
marathon_df.shape

# %%
# Calculate the z-score for each data point in the 'data' column
marathon_df['speed_z_score'] = zscore(marathon_df['Speed_Km/Hr'])

# Filter the DataFrame to remove outliers
marathon_df[(marathon_df['speed_z_score'] > 3) | (marathon_df['speed_z_score'] < -3)].shape

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# ![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*ILbJXAzcB3hU4LxAMG6yLw.jpeg)
#
# -------------------

# %% [markdown]
# ### Handling missing values:

# %% [markdown]
# **Why my data has missing values?**
# They may occur at two stages:
# 1. Data Extraction: It is possible that there are problems with extraction process. Errors at data extraction stage are typically easy to find and can be corrected easily as well.
# 2. Data collection: These errors occur at time of data collection and are harder to correct.
#
# **Why do we need to handle the missing data?**
# To avoid:
# - Bias the conclusions.
# - Leading the business to make wrong decisions.
#
# **Which are the methods to treat missing values ?**
# 1. Deletion: we delete rows where any of the variable is missing. Simplicity is one of the major advantage of this method, but this method reduces the power of model because it reduces the sample size.
#
# 2. Imputation: is a method to fill in the missing values with estimated ones. This imputation is one of the most frequently used methods.
#
#     2.1. Mean/ Mode/ Median Imputation: It consists of replacing the missing data for a given attribute by the mean or median (quantitative attribute) or mode (qualitative attribute) of all known values of that variable.
#     > It can be of two types:
#     > - Generalized Imputation: In this case, we calculate the mean or median for all non missing values of that variable then replace missing value with mean or median.
#     > - Similar case Imputation: In this case, we calculate average for each group individually of non missing values then replace the missing value based on the group.
#
#     2.2. Constant Value
#
#     2.3. Forward Filling
#
#     2.4. Backward Filling
#
#     2.5. Prediction Model:  Prediction model is one of the sophisticated method for handling missing data. Here, we create a predictive model to estimate values that will substitute the missing data.  In this case, we divide our data set into two sets: One set with no missing values for the variable and another one with missing values. First data set become training data set of the model while second data set with missing values is test data set and variable with missing values is treated as target variable. Next, we create a model to predict target variable based on other attributes of the training data set and populate missing values of test data set.
#
# > There are 2 drawbacks for this approach:
# > - The model estimated values are usually more well-behaved than the true values
# > - If there are no relationships with attributes in the data set and the attribute with missing values, then the model will not be precise for estimating missing values.
#
#     2.6. KNN Imputation: In this method of imputation, the missing values of an attribute are imputed using the given number of attributes that are most similar to the attribute whose values are missing. The similarity of two attributes is determined using a distance function. It is also known to have certain advantage & disadvantages.
#
#    > **Advantages:**
#    > - k-nearest neighbour can predict both qualitative & quantitative attributes
#    > - Creation of predictive model for each attribute with missing data is not required
#    > - Attributes with multiple missing values can be easily treated
#    > - Correlation structure of the data is taken into consideration
#
#    > **Disadvantage:**
#    > - KNN algorithm is very time-consuming in analyzing large database. It searches through all the dataset looking for the most similar instances.
#    > - Choice of k-value is very critical. Higher value of k would include attributes which are significantly different from what we need whereas lower value of k implies missing out of significant attributes.
#
# --------------------

# %%
marathon_df.isnull().sum().sort_values(ascending = False)
# Out:
# Nationality    306
# Chip Time       76
# Speed           76
# Pace            76
# Rank             0
# Gender Rank      0
# Gender           0
# Category         0
# Gun Time         0
# Distance         0
# dtype: int64

# %%
# assume they did not attened since no time for chipping
marathon_df[marathon_df['Chip Time'].isnull()]
# Out:
#      Rank Gender Rank  Gender        Category         Nationality  \
# 761     -           -  Female        10KM RUN  [img:flags/SA.gif]
# 762     -           -  Female        10KM RUN  [img:flags/SA.gif]
# 763     -           -  Female        10KM RUN  [img:flags/LB.gif]
# 764     -           -  Female        10KM RUN  [img:flags/CA.gif]
# 765     -           -  Female        10KM RUN                 NaN
# ...   ...         ...     ...             ...                 ...
# 6283    -           -    Male        MARATHON  [img:flags/SA.gif]
# 6377    -           -  Female  MARATHON ELITE  [img:flags/ET.gif]
# 6388    -           -    Male  MARATHON ELITE  [img:flags/KE.gif]
# 6389    -           -    Male  MARATHON ELITE  [img:flags/KE.gif]
# 6390    -           -    Male  MARATHON ELITE  [img:flags/KE.gif]
#
#                   Gun Time Chip Time Speed Pace Distance
# 761   [32384.739|hh:mm:ss]       NaN   NaN  NaN     5 KM
# 762   [32384.739|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 763   [32384.739|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 764   [32384.739|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 765   [32384.739|hh:mm:ss]       NaN   NaN  NaN     0 KM
# ...                    ...       ...   ...  ...      ...
# 6283   [22526.31|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 6377   [22526.31|hh:mm:ss]       NaN   NaN  NaN     0 KM
# 6388   [22526.31|hh:mm:ss]       NaN   NaN  NaN    40 KM
# 6389   [22526.31|hh:mm:ss]       NaN   NaN  NaN    35 KM
# 6390   [22526.31|hh:mm:ss]       NaN   NaN  NaN    30 KM
#
# [76 rows x 10 columns]

# %%
marathon_df[marathon_df['Chip Time'].isnull()].isnull().sum()
# Out:
# Rank            0
# Gender Rank     0
# Gender          0
# Category        0
# Nationality     8
# Gun Time        0
# Chip Time      76
# Speed          76
# Pace           76
# Distance        0
# dtype: int64

# %%
marathon_df.dropna(subset=['Chip Time', 'Speed', 'Pace'], inplace=True)

# %%
marathon_df.isnull().sum().sort_values(ascending = False)
# Out:
# Nationality    298
# Rank             0
# Gender Rank      0
# Gender           0
# Category         0
# Gun Time         0
# Chip Time        0
# Speed            0
# Pace             0
# Distance         0
# dtype: int64

# %%
marathon_df[marathon_df['Nationality'].isnull()]
# Out:
#             Rank Gender Rank  Gender  Category Nationality      Gun Time  \
# 6     130 / 2285     7 / 761  Female  10KM RUN         NaN  00:51:21.156
# 27    360 / 2285    28 / 761  Female  10KM RUN         NaN  00:59:46.301
# 39    455 / 2285    40 / 761  Female  10KM RUN         NaN  01:04:04.435
# 51    530 / 2285    52 / 761  Female  10KM RUN         NaN  01:05:52.357
# 54    536 / 2285    55 / 761  Female  10KM RUN         NaN  01:04:46.663
# ...          ...         ...     ...       ...         ...           ...
# 6316           -           -    Male  MARATHON         NaN  03:32:04.083
# 6317           -           -    Male  MARATHON         NaN  03:32:04.708
# 6330           -           -    Male  MARATHON         NaN  03:31:09.051
# 6351           -           -    Male  MARATHON         NaN  03:56:48.878
# 6367           -           -    Male  MARATHON         NaN  04:53:55.101
#
#          Chip Time       Speed         Pace Distance
# 6     00:51:09.616  11.7 Km/Hr  5:06 min/km    10 KM
# 27    00:59:44.562  10.0 Km/Hr  5:58 min/km    10 KM
# 39    01:02:13.336   9.6 Km/Hr  6:13 min/km    10 KM
# 51    01:04:16.292   9.3 Km/Hr  6:25 min/km    10 KM
# 54    01:04:21.924   9.3 Km/Hr  6:26 min/km    10 KM
# ...            ...         ...          ...      ...
# 6316  02:49:43.336  14.9 Km/Hr  4:01 min/km  42.2 KM
# 6317  02:49:44.087  14.9 Km/Hr  4:01 min/km  42.2 KM
# 6330  03:17:46.863  12.8 Km/Hr  4:41 min/km  42.2 KM
# 6351  03:42:10.789  11.3 Km/Hr  5:15 min/km  42.2 KM
# 6367  04:53:55.101   8.6 Km/Hr  6:57 min/km  42.2 KM
#
# [298 rows x 10 columns]

# %%
#other column data is good, so we assume that this missing during collecting data (filling form)
marathon_df['Nationality'].fillna('Unknown!', inplace=True)
# Out:
# /var/folders/9n/yvd02hfx57z6hx0832zwsdrr0000gn/T/ipykernel_16870/163565897.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   marathon_df['Nationality'].fillna('Unknown!', inplace=True)

# %%
marathon_df.isnull().sum().sort_values(ascending = False)
# Out:
# Rank           0
# Gender Rank    0
# Gender         0
# Category       0
# Nationality    0
# Gun Time       0
# Chip Time      0
# Speed          0
# Pace           0
# Distance       0
# dtype: int64

# %%
marathon_df[(marathon_df['Rank']=='-')]
# Out:
#      Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 770     -           -  Female  10KM RUN  [img:flags/SA.gif]  00:42:05.165
# 771     -           -  Female  10KM RUN  [img:flags/IN.gif]  01:04:07.034
# 772     -           -  Female  10KM RUN  [img:flags/PT.gif]  01:18:07.863
# 773     -           -  Female  10KM RUN  [img:flags/PH.gif]  01:18:46.940
# 774     -           -  Female  10KM RUN  [img:flags/PH.gif]  01:22:28.217
# ...   ...         ...     ...       ...                 ...           ...
# 6364    -           -    Male  MARATHON  [img:flags/SA.gif]  04:29:23.849
# 6365    -           -    Male  MARATHON  [img:flags/AF.gif]  04:42:13.532
# 6366    -           -    Male  MARATHON  [img:flags/SA.gif]  04:53:02.507
# 6367    -           -    Male  MARATHON            Unknown!  04:53:55.101
# 6368    -           -    Male  MARATHON  [img:flags/SA.gif]  04:55:15.850
#
#          Chip Time       Speed         Pace Distance
# 770   00:42:05.165  14.2 Km/Hr  4:12 min/km    10 KM
# 771   01:04:07.034   9.3 Km/Hr  6:24 min/km    10 KM
# 772   01:18:07.863   7.6 Km/Hr  7:48 min/km    10 KM
# 773   01:18:46.940   7.6 Km/Hr  7:52 min/km    10 KM
# 774   01:22:28.217   7.2 Km/Hr  8:14 min/km    10 KM
# ...            ...         ...          ...      ...
# 6364  04:17:28.782   9.8 Km/Hr  6:06 min/km  42.2 KM
# 6365  04:30:08.835   9.3 Km/Hr  6:24 min/km  42.2 KM
# 6366  04:41:14.383   9.0 Km/Hr  6:39 min/km  42.2 KM
# 6367  04:53:55.101   8.6 Km/Hr  6:57 min/km  42.2 KM
# 6368  04:55:15.850   8.5 Km/Hr  6:59 min/km  42.2 KM
#
# [197 rows x 10 columns]

# %%
marathon_df['Rank'] = marathon_df['Rank'].map(lambda x : '0 / 0' if x == '-' else x )

# %%
marathon_df['Gender Rank'] = marathon_df['Gender Rank'].map(lambda x : '0 / 0' if x == '-' else x )

# %%
marathon_df[(marathon_df['Rank']=='0 / 0')]
# Out:
#        Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 770   0 / 0       0 / 0  Female  10KM RUN  [img:flags/SA.gif]  00:42:05.165
# 771   0 / 0       0 / 0  Female  10KM RUN  [img:flags/IN.gif]  01:04:07.034
# 772   0 / 0       0 / 0  Female  10KM RUN  [img:flags/PT.gif]  01:18:07.863
# 773   0 / 0       0 / 0  Female  10KM RUN  [img:flags/PH.gif]  01:18:46.940
# 774   0 / 0       0 / 0  Female  10KM RUN  [img:flags/PH.gif]  01:22:28.217
# ...     ...         ...     ...       ...                 ...           ...
# 6364  0 / 0       0 / 0    Male  MARATHON  [img:flags/SA.gif]  04:29:23.849
# 6365  0 / 0       0 / 0    Male  MARATHON  [img:flags/AF.gif]  04:42:13.532
# 6366  0 / 0       0 / 0    Male  MARATHON  [img:flags/SA.gif]  04:53:02.507
# 6367  0 / 0       0 / 0    Male  MARATHON            Unknown!  04:53:55.101
# 6368  0 / 0       0 / 0    Male  MARATHON  [img:flags/SA.gif]  04:55:15.850
#
#          Chip Time       Speed         Pace Distance
# 770   00:42:05.165  14.2 Km/Hr  4:12 min/km    10 KM
# 771   01:04:07.034   9.3 Km/Hr  6:24 min/km    10 KM
# 772   01:18:07.863   7.6 Km/Hr  7:48 min/km    10 KM
# 773   01:18:46.940   7.6 Km/Hr  7:52 min/km    10 KM
# 774   01:22:28.217   7.2 Km/Hr  8:14 min/km    10 KM
# ...            ...         ...          ...      ...
# 6364  04:17:28.782   9.8 Km/Hr  6:06 min/km  42.2 KM
# 6365  04:30:08.835   9.3 Km/Hr  6:24 min/km  42.2 KM
# 6366  04:41:14.383   9.0 Km/Hr  6:39 min/km  42.2 KM
# 6367  04:53:55.101   8.6 Km/Hr  6:57 min/km  42.2 KM
# 6368  04:55:15.850   8.5 Km/Hr  6:59 min/km  42.2 KM
#
# [197 rows x 10 columns]

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
marathon_df.head(2)
# Out:
#         Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 0  46 / 2285     1 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556
# 1  53 / 2285     2 / 761  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175
#
#       Chip Time       Speed         Pace Distance
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM

# %%
marathon_df.dtypes
# Out:
# Rank           object
# Gender Rank    object
# Gender         object
# Category       object
# Nationality    object
# Gun Time       object
# Chip Time      object
# Speed          object
# Pace           object
# Distance       object
# dtype: object

# %%
marathon_df['Rank_Total'] = marathon_df['Rank'].map(lambda x: int(x.split('/')[1]))
marathon_df['Rank'] = marathon_df['Rank'].map(lambda x: int(x.split('/')[0]))

# %%
marathon_df.head()
# Out:
#    Rank Gender Rank  Gender  Category         Nationality      Gun Time  \
# 0    46     1 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:42:59.556
# 1    53     2 / 761  Female  10KM RUN  [img:flags/CZ.gif]  00:43:28.175
# 2    55     3 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:44:00.251
# 3    88     4 / 761  Female  10KM RUN  [img:flags/MA.gif]  00:48:28.115
# 4    93     5 / 761  Female  10KM RUN  [img:flags/SA.gif]  00:58:37.753
#
#       Chip Time       Speed         Pace Distance  Rank_Total
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM        2285
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM        2285
# 2  00:43:56.317  13.6 Km/Hr  4:23 min/km    10 KM        2285
# 3  00:48:22.908  12.4 Km/Hr  4:50 min/km    10 KM        2285
# 4  00:48:27.714  12.3 Km/Hr  4:50 min/km    10 KM        2285

# %%
marathon_df['Gender_Rank_Total'] = marathon_df['Gender Rank'].map(lambda x: int(x.split('/')[1]))
marathon_df['Gender Rank'] = marathon_df['Gender Rank'].map(lambda x: int(x.split('/')[0]))

# %%
marathon_df.dtypes
# Out:
# Rank                  int64
# Gender Rank           int64
# Gender               object
# Category             object
# Nationality          object
# Gun Time             object
# Chip Time            object
# Speed                object
# Pace                 object
# Distance             object
# Rank_Total            int64
# Gender_Rank_Total     int64
# dtype: object

# %%
marathon_df['Nationality'] = marathon_df['Nationality'].map(lambda x : x if x=='Unknown!' else x.split('/')[1].split('.')[0])

# %%
# you could use regular experssion 
# https://regex-generator.olafneumann.org/

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality      Gun Time  \
# 0    46            1  Female  10KM RUN          SA  00:42:59.556
# 1    53            2  Female  10KM RUN          CZ  00:43:28.175
#
#       Chip Time       Speed         Pace Distance  Rank_Total  \
# 0  00:42:57.505  13.9 Km/Hr  4:17 min/km    10 KM        2285
# 1  00:43:24.774  13.8 Km/Hr  4:20 min/km    10 KM        2285
#
#    Gender_Rank_Total
# 0                761
# 1                761

# %%
marathon_df.dtypes
# Out:
# Rank                  int64
# Gender Rank           int64
# Gender               object
# Category             object
# Nationality          object
# Gun Time             object
# Chip Time            object
# Speed                object
# Pace                 object
# Distance             object
# Rank_Total            int64
# Gender_Rank_Total     int64
# dtype: object

# %%
#marathon_df['Chip Time'] = pd.to_datetime(marathon_df['Chip Time'], format='%H:%M:%S.%f')
#marathon_df['Chip Time'] = marathon_df['Chip Time'].dt.floor('s')

#marathon_df['Gun Time'] = pd.to_datetime(marathon_df['Gun Time'], format='%H:%M:%S.%f')
#marathon_df['Gun Time'] = marathon_df['Gun Time'].dt.floor('s')

# %%
marathon_df['Chip Time'] = pd.to_timedelta(marathon_df['Chip Time'])
marathon_df['Gun Time'] = pd.to_timedelta(marathon_df['Gun Time'])

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time       Speed         Pace Distance  Rank_Total  \
# 0 0 days 00:42:57.505000  13.9 Km/Hr  4:17 min/km    10 KM        2285
# 1 0 days 00:43:24.774000  13.8 Km/Hr  4:20 min/km    10 KM        2285
#
#    Gender_Rank_Total
# 0                761
# 1                761

# %%
marathon_df.dtypes
# Out:
# Rank                           int64
# Gender Rank                    int64
# Gender                        object
# Category                      object
# Nationality                   object
# Gun Time             timedelta64[ns]
# Chip Time            timedelta64[ns]
# Speed                         object
# Pace                          object
# Distance                      object
# Rank_Total                     int64
# Gender_Rank_Total              int64
# dtype: object

# %%
marathon_df['Speed'] = marathon_df['Speed'].map(lambda x : float(x.split()[0]))

# %%
# to not forget information about speed
marathon_df.rename(columns={'Speed': 'Speed_Km/Hr'}, inplace=True)

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr         Pace Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9  4:17 min/km    10 KM        2285
# 1 0 days 00:43:24.774000         13.8  4:20 min/km    10 KM        2285
#
#    Gender_Rank_Total
# 0                761
# 1                761

# %%
marathon_df.dtypes
# Out:
# Rank                           int64
# Gender Rank                    int64
# Gender                        object
# Category                      object
# Nationality                   object
# Gun Time             timedelta64[ns]
# Chip Time            timedelta64[ns]
# Speed_Km/Hr                  float64
# Pace                          object
# Distance                      object
# Rank_Total                     int64
# Gender_Rank_Total              int64
# dtype: object

# %%
marathon_df['Pace'].map(lambda x : x.split()[1]).value_counts()
# Out:
# Pace
# min/km    6227
# Name: count, dtype: int64

# %%
# marathon_df['Pace'] = pd.to_timedelta(marathon_df['Pace'].map(lambda x : '00:'+x.split()[0]))

# %%
def convert_pace(str_pace):
    time = str_pace.split(':')
    new_time = int(time[0]) + int(time[1])/60
    return round(new_time, 2)

# %%
marathon_df['Pace'] = marathon_df['Pace'].map(lambda x: x.split(' ')[0])
marathon_df['Pace'] = marathon_df['Pace'].map(convert_pace)
# to not forget information about speed
marathon_df.rename(columns={'Pace': 'Pace_min_Km'}, inplace=True)

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9         4.28    10 KM        2285
# 1 0 days 00:43:24.774000         13.8         4.33    10 KM        2285
#
#    Gender_Rank_Total
# 0                761
# 1                761

# %%
marathon_df.dtypes
# Out:
# Rank                           int64
# Gender Rank                    int64
# Gender                        object
# Category                      object
# Nationality                   object
# Gun Time             timedelta64[ns]
# Chip Time            timedelta64[ns]
# Speed_Km/Hr                  float64
# Pace_min_Km                  float64
# Distance                      object
# Rank_Total                     int64
# Gender_Rank_Total              int64
# dtype: object

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %% [markdown]
# **How to remove Outliers?**
# Most of the ways to deal with outliers are similar to the methods of missing values like deleting rows, transforming them, binning them, treat them as a separate group, imputing values and other statistical methods. Here, we will discuss the common techniques used to deal with outliers:
#
# 1. Deleting rows: We delete outlier values if it is due to data entry error, data processing error or outlier rows are very small in numbers. We can also use trimming at both ends to remove outliers.
#
# 2. Imputing: Like imputation of missing values, we can also impute outliers. We can use mean, median, mode imputation methods. Before imputing values, we should analyse if it is natural outlier or artificial. If it is artificial, we can go with imputing values. We can also use statistical model to predict values of outlier rows and after that we can impute it with predicted values.
#
# 3. Treat separately: If there are significant number of outliers, we should treat them separately in the statistical model. One of the approach is to treat both groups as two different groups and build individual model for both groups and then combine the output.

# %%
marathon_df = marathon_df[(marathon_df['speed_z_score'] <= 3) & (marathon_df['speed_z_score'] >= -3)]

# %% [markdown]
# ## 3. Univariate Analysis:
#
# This involves examining single variables to understand their characteristics (distribution, central tendency, dispersion, and shape).
#
# We calculate **numerical values** about the data that tells us about the distribution of the data. We also **draw graphs** showing visually how the data is distributed. **To answer the following questions about Features/characteristics of Data:**
# - Where is the center of the data? (location)
# - How much does the data vary? (scale)
# - What is the shape of the data? (shape)
#
# **The benefits of this analysis:**
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# **In this step, we will explore variables one by one using following approaches:**

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9         4.28    10 KM        2285
# 1 0 days 00:43:24.774000         13.8         4.33    10 KM        2285
#
#    Gender_Rank_Total
# 0                761
# 1                761

# %%
marathon_df.dtypes
# Out:
# Rank                           int64
# Gender Rank                    int64
# Gender                        object
# Category                      object
# Nationality                   object
# Gun Time             timedelta64[ns]
# Chip Time            timedelta64[ns]
# Speed_Km/Hr                  float64
# Pace_min_Km                  float64
# Distance                      object
# Rank_Total                     int64
# Gender_Rank_Total              int64
# dtype: object

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %%
counts_gender = marathon_df['Gender'].value_counts()
counts_gender
# Out:
# Gender
# Male      4097
# Female    2130
# Name: count, dtype: int64

# %%
counts_gender.values
# Out:
# array([4097, 2130])

# %%
plt.pie(x=counts_gender.values,
        labels=counts_gender.index,
        startangle=45,
        shadow=True,
        explode = [0.3,0.2]
       )
plt.show()

# %%
distance_counts = marathon_df["Distance"].value_counts()
distance_counts
# Out:
# Distance
# 10 KM      2352
# 4 KM       2225
# 21.1 KM    1158
# 42.2 KM     492
# Name: count, dtype: int64

# %%
category_counts = marathon_df["Category"].value_counts()
category_counts
# Out:
# Category
# 10KM RUN               2352
# 4KM FUN RUN            2225
# HALF MARATHON          1152
# MARATHON                474
# MARATHON ELITE           18
# HALF MARATHON ELITE       6
# Name: count, dtype: int64

# %%
plt.bar(distance_counts.index,
        distance_counts.values,
        color=['green', 'blue', 'red', 'lavender']
       )
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(11,8))
sns.countplot(data=marathon_df,
              x="Category")
# plt.title("Number of Runners per Category")
# plt.ylabel("Number of Runners")
plt.show()

# %%
sns.barplot(x="Distance", y="count",data=distance_counts.to_frame());

# %%
top_nat_counts = marathon_df["Nationality"].value_counts().head(10)
top_nat_counts
# Out:
# Nationality
# SA          3346
# PH           452
# Unknown!     298
# IN           239
# GB           210
# EG           206
# PK           154
# JO           122
# LB           120
# MY            80
# Name: count, dtype: int64

# %%
type(top_nat_counts)
# Out:
# pandas.core.series.Series

# %%
sns.barplot(y="Nationality", x="count",data=top_nat_counts.to_frame());

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9         4.28    10 KM        2285
# 1 0 days 00:43:24.774000         13.8         4.33    10 KM        2285
#
#    Gender_Rank_Total
# 0                761
# 1                761

# %%
plt.hist(marathon_df['Speed_Km/Hr'],facecolor = 'b', edgecolor = 'red', bins = 15) # bins = 6 means 6 bars
plt.xlabel('Speed_Km/Hr')
plt.ylabel('Frequency')
plt.title(f'Histogram of Speed_Km/Hr')
plt.show()

# %%
## Note: The insights would be taking for each race individually 
marathon_4KM_df = marathon_df[marathon_df["Category"]=='4KM FUN RUN']
marathon_10KM_df = marathon_df[marathon_df["Category"]=='10KM RUN']
marathon_21KM_df = marathon_df[marathon_df["Category"]=='HALF MARATHON']
marathon_21KM_e_df = marathon_df[marathon_df["Category"]=='HALF MARATHON ELITE']
marathon_42KM_df = marathon_df[marathon_df["Category"]=='MARATHON']
marathon_42KM_e_df = marathon_df[marathon_df["Category"]=='MARATHON ELITE']

# %%
# Create a figure and an array of axes with a subplot for each histogram
fig, axes = plt.subplots(2, 3, figsize=(15, 5))

# Plot a histogram for each dataset using plt.hist
axes[0][0].hist(marathon_4KM_df['Speed_Km/Hr'],edgecolor = 'red', bins=100, alpha=0.7, color='blue')
axes[0][0].set_title('Histogram for 4KM')

axes[0][1].hist(marathon_10KM_df['Speed_Km/Hr'], edgecolor = 'red', bins=20, alpha=0.7, color='green')
axes[0][1].set_title('Histogram for 10KM')

axes[0][2].hist(marathon_21KM_df['Speed_Km/Hr'], edgecolor = 'red', bins=20, alpha=0.7, color='red')
axes[0][2].set_title('Histogram for 21KM')

axes[1][0].hist(marathon_42KM_df['Speed_Km/Hr'], edgecolor = 'red', bins=20, alpha=0.7, color='orange')
axes[1][0].set_title('Histogram for 42KM')

axes[1][1].hist(marathon_21KM_e_df['Speed_Km/Hr'],edgecolor = 'red', bins=5, alpha=0.7, color='grey')
axes[1][1].set_title('Histogram for 21KM elit')

axes[1][2].hist(marathon_42KM_e_df['Speed_Km/Hr'],edgecolor = 'red', bins=5, alpha=0.7, color='grey')
axes[1][2].set_title('Histogram for 42KM elit')

# Display the plots
plt.tight_layout()
plt.show()

# %%
# Stacked Histogram separated by origin
plt.figure(figsize=(15,8))
sns.histplot(
    marathon_df,
    x="Speed_Km/Hr",
    hue="Category", # color of plot elements
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8)
# Out:
# <Axes: xlabel='Speed_Km/Hr', ylabel='Count'>

# %%
plt.boxplot(marathon_df['Speed_Km/Hr'])
plt.xlabel('Speed_Km/Hr')
plt.ylabel('Frequency')
plt.title(f'Box plot of Speed_Km/Hr')
plt.show()

# %%
plt.figure(figsize=(15,8))

sns.boxplot(
    marathon_df,
    y="Speed_Km/Hr",
    hue="Category")
# Out:
# <Axes: ylabel='Speed_Km/Hr'>

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    marathon_df,
    x="Pace_min_Km",
    hue="Category", # color of plot elements
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8)
# Out:
# <Axes: xlabel='Pace_min_Km', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))

sns.boxplot(
    marathon_df,
    y="Pace_min_Km",
    hue="Category")
# Out:
# <Axes: ylabel='Pace_min_Km'>

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9         4.28    10 KM        2285
# 1 0 days 00:43:24.774000         13.8         4.33    10 KM        2285
#
#    Gender_Rank_Total
# 0                761
# 1                761

# %%
# called feature engineering
marathon_df['Chip Time duration-min'] = marathon_df['Chip Time'].dt.total_seconds()/60
marathon_df['Chip Time duration-min'] = marathon_df['Chip Time duration-min'].apply(lambda x: np.round(x, 2))
marathon_df['Gun Time duration-min'] = marathon_df['Gun Time'].dt.total_seconds()/60
marathon_df['Gun Time duration-min'] = marathon_df['Gun Time duration-min'].apply(lambda x: np.round(x, 2))

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9         4.28    10 KM        2285
# 1 0 days 00:43:24.774000         13.8         4.33    10 KM        2285
#
#    Gender_Rank_Total  Chip Time duration-min  Gun Time duration-min
# 0                761                   42.96                  42.99
# 1                761                   43.41                  43.47

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    marathon_df,
    x='Chip Time duration-min',
    hue="Category", # color of plot elements
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8)
# Out:
# <Axes: xlabel='Chip Time duration-min', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))
sns.histplot(
    marathon_df,
    x='Gun Time duration-min',
    hue="Category", # color of plot elements
    multiple="stack", # also can be layer or dodge or fill
    alpha=0.8)
# Out:
# <Axes: xlabel='Gun Time duration-min', ylabel='Count'>

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9         4.28    10 KM        2285
# 1 0 days 00:43:24.774000         13.8         4.33    10 KM        2285
#
#    Gender_Rank_Total  Chip Time duration-min  Gun Time duration-min
# 0                761                   42.96                  42.99
# 1                761                   43.41                  43.47

# %%
plt.figure(figsize=(15,8))

sns.boxplot(
    marathon_df,
    y='Chip Time duration-min',
    hue="Category")
# Out:
# <Axes: ylabel='Chip Time duration-min'>

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %%
marathon_df.describe().T
# Out:
#                          count                       mean  \
# Rank                    6227.0                 928.820299
# Gender Rank             6227.0                  510.98651
# Gun Time                  6227  0 days 01:40:26.067858679
# Chip Time                 6227  0 days 01:34:00.664645254
# Speed_Km/Hr             6227.0                   7.809571
# Pace_min_Km             6227.0                   8.538052
# Rank_Total              6227.0                1856.672234
# Gender_Rank_Total       6227.0                1021.004657
# Chip Time duration-min  6227.0                  94.011071
# Gun Time duration-min   6227.0                 100.434495
#
#                                               std                     min  \
# Rank                                    664.99726                     0.0
# Gender Rank                            378.504283                     0.0
# Gun Time                0 days 01:13:11.546034299  0 days 00:12:52.781000
# Chip Time               0 days 01:08:47.363020329  0 days 00:12:52.781000
# Speed_Km/Hr                              2.738633                     2.1
# Pace_min_Km                              2.975501                     1.8
# Rank_Total                             681.637586                     0.0
# Gender_Rank_Total                      411.210106                     0.0
# Chip Time duration-min                   68.78933                   12.88
# Gun Time duration-min                   73.192392                   12.88
#
#                                            25%                     50%  \
# Rank                                     334.5                   840.0
# Gender Rank                              185.0                   460.0
# Gun Time                0 days 00:48:06.457500  0 days 01:16:01.507000
# Chip Time               0 days 00:45:33.614000  0 days 01:12:38.800000
# Speed_Km/Hr                                5.8                     7.4
# Pace_min_Km                               6.43                     8.0
# Rank_Total                              1128.0                  2220.0
# Gender_Rank_Total                        761.0                  1038.0
# Chip Time duration-min                   45.56                   72.65
# Gun Time duration-min                    48.11                   76.03
#
#                                            75%                     max
# Rank                                    1474.5                  2285.0
# Gender Rank                              774.0                  1524.0
# Gun Time                0 days 02:09:54.523000  0 days 06:20:21.380000
# Chip Time               0 days 01:57:57.833000  0 days 06:14:05.366000
# Speed_Km/Hr                                9.3                    33.1
# Pace_min_Km                               10.2                   27.93
# Rank_Total                              2285.0                  2285.0
# Gender_Rank_Total                       1182.0                  1524.0
# Chip Time duration-min                 117.965                  374.09
# Gun Time duration-min                   129.91                  380.36

# %%
# describe(include=’all’) provides a statistics summary of all data, include object, category etc
marathon_df.describe(include='all').T
# Out:
#                          count unique       top  freq  \
# Rank                    6227.0    NaN       NaN   NaN
# Gender Rank             6227.0    NaN       NaN   NaN
# Gender                    6227      2      Male  4097
# Category                  6227      6  10KM RUN  2352
# Nationality               6227     86        SA  3346
# Gun Time                  6227    NaN       NaN   NaN
# Chip Time                 6227    NaN       NaN   NaN
# Speed_Km/Hr             6227.0    NaN       NaN   NaN
# Pace_min_Km             6227.0    NaN       NaN   NaN
# Distance                  6227      4     10 KM  2352
# Rank_Total              6227.0    NaN       NaN   NaN
# Gender_Rank_Total       6227.0    NaN       NaN   NaN
# Chip Time duration-min  6227.0    NaN       NaN   NaN
# Gun Time duration-min   6227.0    NaN       NaN   NaN
#
#                                              mean                        std  \
# Rank                                   928.820299                  664.99726
# Gender Rank                             510.98651                 378.504283
# Gender                                        NaN                        NaN
# Category                                      NaN                        NaN
# Nationality                                   NaN                        NaN
# Gun Time                0 days 01:40:26.067858679  0 days 01:13:11.546034299
# Chip Time               0 days 01:34:00.664645254  0 days 01:08:47.363020329
# Speed_Km/Hr                              7.809571                   2.738633
# Pace_min_Km                              8.538052                   2.975501
# Distance                                      NaN                        NaN
# Rank_Total                            1856.672234                 681.637586
# Gender_Rank_Total                     1021.004657                 411.210106
# Chip Time duration-min                  94.011071                   68.78933
# Gun Time duration-min                  100.434495                  73.192392
#
#                                            min                     25%  \
# Rank                                       0.0                   334.5
# Gender Rank                                0.0                   185.0
# Gender                                     NaN                     NaN
# Category                                   NaN                     NaN
# Nationality                                NaN                     NaN
# Gun Time                0 days 00:12:52.781000  0 days 00:48:06.457500
# Chip Time               0 days 00:12:52.781000  0 days 00:45:33.614000
# Speed_Km/Hr                                2.1                     5.8
# Pace_min_Km                                1.8                    6.43
# Distance                                   NaN                     NaN
# Rank_Total                                 0.0                  1128.0
# Gender_Rank_Total                          0.0                   761.0
# Chip Time duration-min                   12.88                   45.56
# Gun Time duration-min                    12.88                   48.11
#
#                                            50%                     75%  \
# Rank                                     840.0                  1474.5
# Gender Rank                              460.0                   774.0
# Gender                                     NaN                     NaN
# Category                                   NaN                     NaN
# Nationality                                NaN                     NaN
# Gun Time                0 days 01:16:01.507000  0 days 02:09:54.523000
# Chip Time               0 days 01:12:38.800000  0 days 01:57:57.833000
# Speed_Km/Hr                                7.4                     9.3
# Pace_min_Km                                8.0                    10.2
# Distance                                   NaN                     NaN
# Rank_Total                              2220.0                  2285.0
# Gender_Rank_Total                       1038.0                  1182.0
# Chip Time duration-min                   72.65                 117.965
# Gun Time duration-min                    76.03                  129.91
#
#                                            max
# Rank                                    2285.0
# Gender Rank                             1524.0
# Gender                                     NaN
# Category                                   NaN
# Nationality                                NaN
# Gun Time                0 days 06:20:21.380000
# Chip Time               0 days 06:14:05.366000
# Speed_Km/Hr                               33.1
# Pace_min_Km                              27.93
# Distance                                   NaN
# Rank_Total                              2285.0
# Gender_Rank_Total                       1524.0
# Chip Time duration-min                  374.09
# Gun Time duration-min                   380.36

# %%
marathon_df['Pace_min_Km'].mean(), marathon_df['Pace_min_Km'].std()
# Out:
# (8.53805203147583, 2.975501460547262)

# %%
np.quantile(marathon_df['Pace_min_Km'],0.25)
# Out:
# 6.43

# %%
marathon_df['Pace_min_Km'].quantile(0.25)
# Out:
# 6.43

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:
#
# Here, you look at the relationships between two or more variables. This can involve looking for correlations, patterns, and trends that suggest a relationship or an association.
#
# We can perform bi-variate analysis for any combination of categorical and numerical variables. The combination can be:
# | bi-variate variables   | Plot type |
# | ------------- | ------------- |
# | Categorical & Categorical| Stacked Bar Chart |
# | Categorical & numerical  | scatter plot, histogram, box plot|
# | numerical  & numerical  | Scatter plot, line chart|
#
#
# Multivariate Analysis:
# - Heat map
# - Bar Chart
# - Scatter Chart
# - Line Chart

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.

# %%
# above is example of negative correlation

# %%
marathon_df.head(2)
# Out:
#    Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 0    46            1  Female  10KM RUN          SA 0 days 00:42:59.556000
# 1    53            2  Female  10KM RUN          CZ 0 days 00:43:28.175000
#
#                Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 0 0 days 00:42:57.505000         13.9         4.28    10 KM        2285
# 1 0 days 00:43:24.774000         13.8         4.33    10 KM        2285
#
#    Gender_Rank_Total  Chip Time duration-min  Gun Time duration-min
# 0                761                   42.96                  42.99
# 1                761                   43.41                  43.47

# %%
#Create a correlation matrix to show relationship between select variables
corr_matrix = marathon_df.corr()
corr_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[205], line 2
#       1 #Create a correlation matrix to show relationship between select variables
# ----> 2 corr_matrix = marathon_df.corr()
#       3 corr_matrix
#
# File ~/DP/lib/python3.11/site-packages/pandas/core/frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/DP/lib/python3.11/site-packages/pandas/core/frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File ~/DP/lib/python3.11/site-packages/pandas/core/internals/managers.py:1693, in BlockManager.as_array(self, dtype, copy, na_value)
#    1691         arr.flags.writeable = False
#    1692 else:
# -> 1693     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1694     # The underlying data was copied within _interleave, so no need
#    1695     # to further copy if copy=True or setting na_value
#    1697 if na_value is lib.no_default:
#
# File ~/DP/lib/python3.11/site-packages/pandas/core/internals/managers.py:1752, in BlockManager._interleave(self, dtype, na_value)
#    1750     else:
#    1751         arr = blk.get_values(dtype)
# -> 1752     result[rl.indexer] = arr
#    1753     itemmask[rl.indexer] = 1
#    1755 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Female'

# %%
corr_matrix = marathon_df.select_dtypes(include=np.number).corr()
corr_matrix
# Out:
#                             Rank  Gender Rank  Gun Time  Chip Time  \
# Rank                    1.000000     0.787352 -0.184959  -0.181370
# Gender Rank             0.787352     1.000000 -0.123096  -0.122850
# Gun Time               -0.184959    -0.123096  1.000000   0.995375
# Chip Time              -0.181370    -0.122850  0.995375   1.000000
# Speed_Km/Hr            -0.801222    -0.640630  0.056862   0.047838
# Pace_min_Km             0.821945     0.621220 -0.084773  -0.072660
# Rank_Total              0.512576     0.418657 -0.805632  -0.801603
# Gender_Rank_Total       0.245985     0.543308 -0.625021  -0.626517
# Chip Time duration-min -0.181369    -0.122850  0.995375   1.000000
# Gun Time duration-min  -0.184959    -0.123095  1.000000   0.995375
#
#                         Speed_Km/Hr  Pace_min_Km  Rank_Total  \
# Rank                      -0.801222     0.821945    0.512576
# Gender Rank               -0.640630     0.621220    0.418657
# Gun Time                   0.056862    -0.084773   -0.805632
# Chip Time                  0.047838    -0.072660   -0.801603
# Speed_Km/Hr                1.000000    -0.879847   -0.348157
# Pace_min_Km               -0.879847     1.000000    0.282649
# Rank_Total                -0.348157     0.282649    1.000000
# Gender_Rank_Total         -0.111163     0.043431    0.770509
# Chip Time duration-min     0.047837    -0.072659   -0.801602
# Gun Time duration-min      0.056862    -0.084773   -0.805632
#
#                         Gender_Rank_Total  Chip Time duration-min  \
# Rank                             0.245985               -0.181369
# Gender Rank                      0.543308               -0.122850
# Gun Time                        -0.625021                0.995375
# Chip Time                       -0.626517                1.000000
# Speed_Km/Hr                     -0.111163                0.047837
# Pace_min_Km                      0.043431               -0.072659
# Rank_Total                       0.770509               -0.801602
# Gender_Rank_Total                1.000000               -0.626517
# Chip Time duration-min          -0.626517                1.000000
# Gun Time duration-min           -0.625021                0.995375
#
#                         Gun Time duration-min
# Rank                                -0.184959
# Gender Rank                         -0.123095
# Gun Time                             1.000000
# Chip Time                            0.995375
# Speed_Km/Hr                          0.056862
# Pace_min_Km                         -0.084773
# Rank_Total                          -0.805632
# Gender_Rank_Total                   -0.625021
# Chip Time duration-min               0.995375
# Gun Time duration-min                1.000000

# %%
# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix,
            annot=True, 
            cmap='coolwarm',
            fmt=".1f"
           )

# Show the plot
plt.show()

# %%
marathon_df.columns
# Out:
# Index(['Rank', 'Gender Rank', 'Gender', 'Category', 'Nationality', 'Gun Time',
#        'Chip Time', 'Speed_Km/Hr', 'Pace_min_Km', 'Distance', 'Rank_Total',
#        'Gender_Rank_Total', 'Chip Time duration-min', 'Gun Time duration-min'],
#       dtype='object')

# %%
sns.pairplot(marathon_df[['Category', 'Speed_Km/Hr',
                          'Pace_min_Km','Chip Time duration-min', 
                          'Gun Time duration-min']], 
             hue="Category",
             # palette='coolwarm'
            ); #for numerical values, we use hue for catagorical

# %%
# Q1

# %%
# counts_gender = marathon_df['Gender'].value_counts()
counts_gender
# Out:
# Gender
# Male      4097
# Female    2130
# Name: count, dtype: int64

# %%
plt.pie(counts_gender,
        labels=counts_gender.index,
        normalize=True,
        autopct="%.2f",
        # textprops = {'color':'white'},
        # color=['red', 'blue']
       )
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(x = 'Category', hue = 'Gender', data = marathon_df);

# %%
df_category_pro = marathon_df['Category'].value_counts().reset_index()
df_category_pro.columns = ['Category', 'total_count']
df_category_pro
# Out:
#               Category  total_count
# 0             10KM RUN         2352
# 1          4KM FUN RUN         2225
# 2        HALF MARATHON         1152
# 3             MARATHON          474
# 4       MARATHON ELITE           18
# 5  HALF MARATHON ELITE            6

# %%
df_gender_track_pro = marathon_df[['Category','Gender']].value_counts().reset_index()
df_gender_track_pro
# Out:
#                Category  Gender  count
# 0              10KM RUN    Male   1566
# 1           4KM FUN RUN    Male   1182
# 2           4KM FUN RUN  Female   1043
# 3         HALF MARATHON    Male    926
# 4              10KM RUN  Female    786
# 5              MARATHON    Male    410
# 6         HALF MARATHON  Female    226
# 7              MARATHON  Female     64
# 8        MARATHON ELITE    Male     10
# 9        MARATHON ELITE  Female      8
# 10  HALF MARATHON ELITE  Female      3
# 11  HALF MARATHON ELITE    Male      3

# %%
final_prop = df_gender_track_pro.merge(df_category_pro, on='Category')
final_prop['percentage'] = final_prop[['count', 'total_count']].apply(lambda x: round((x[0]/x[1])*100,2), axis=1)
final_prop
# Out:
# /var/folders/9n/yvd02hfx57z6hx0832zwsdrr0000gn/T/ipykernel_16870/3990637675.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   final_prop['percentage'] = final_prop[['count', 'total_count']].apply(lambda x: round((x[0]/x[1])*100,2), axis=1)
#                Category  Gender  count  total_count  percentage
# 0              10KM RUN    Male   1566         2352       66.58
# 1           4KM FUN RUN    Male   1182         2225       53.12
# 2           4KM FUN RUN  Female   1043         2225       46.88
# 3         HALF MARATHON    Male    926         1152       80.38
# 4              10KM RUN  Female    786         2352       33.42
# 5              MARATHON    Male    410          474       86.50
# 6         HALF MARATHON  Female    226         1152       19.62
# 7              MARATHON  Female     64          474       13.50
# 8        MARATHON ELITE    Male     10           18       55.56
# 9        MARATHON ELITE  Female      8           18       44.44
# 10  HALF MARATHON ELITE  Female      3            6       50.00
# 11  HALF MARATHON ELITE    Male      3            6       50.00

# %%
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(data=final_prop,
                       x='Category',
                       y='percentage',
                       hue='Gender')
for p in bar_plot.patches:
    bar_plot.annotate(format(p.get_height(), '.1f') + '%', 
                      (p.get_x() + p.get_width() / 2., p.get_height()), 
                      ha = 'center', va = 'center', 
                      xytext = (0, 9), 
                      textcoords = 'offset points')

plt.title('Percentage Distribution of Gender by Category')
plt.ylabel('Percentage (%)')
plt.xlabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
marathon_df[['Rank_Total']].value_counts()
# Out:
# Rank_Total
# 2285          2285
# 2220          2220
# 1128          1128
# 373            373
# 0              197
# 18              18
# 6                6
# Name: count, dtype: int64

# %%
marathon_df[['Rank_Total', 'Category']].value_counts()
# Out:
# Rank_Total  Category
# 2285        10KM RUN               2285
# 2220        4KM FUN RUN            2220
# 1128        HALF MARATHON          1128
# 373         MARATHON                373
# 0           MARATHON                101
#             10KM RUN                 67
#             HALF MARATHON            24
# 18          MARATHON ELITE           18
# 6           HALF MARATHON ELITE       6
# 0           4KM FUN RUN               5
# Name: count, dtype: int64

# %%
marathon_df[(marathon_df['Rank_Total'] ==0 ) & (marathon_df['Category']=='MARATHON')]
# Out:
#       Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 5873     0            0  Female  MARATHON          RU 0 days 02:31:17.157000
# 5874     0            0  Female  MARATHON    Unknown! 0 days 02:50:17.875000
# 5875     0            0  Female  MARATHON    Unknown! 0 days 03:30:10.800000
# 5876     0            0  Female  MARATHON          PH 0 days 03:31:41.928000
# 5877     0            0  Female  MARATHON          YE 0 days 03:47:56.322000
# ...    ...          ...     ...       ...         ...                    ...
# 6364     0            0    Male  MARATHON          SA 0 days 04:29:23.849000
# 6365     0            0    Male  MARATHON          AF 0 days 04:42:13.532000
# 6366     0            0    Male  MARATHON          SA 0 days 04:53:02.507000
# 6367     0            0    Male  MARATHON    Unknown! 0 days 04:53:55.101000
# 6368     0            0    Male  MARATHON          SA 0 days 04:55:15.850000
#
#                   Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 5873 0 days 02:18:51.076000         18.2         3.28  42.2 KM           0
# 5874 0 days 02:35:45.195000         16.2         3.68  42.2 KM           0
# 5875 0 days 02:51:58.184000         14.7         4.07  42.2 KM           0
# 5876 0 days 03:18:43.899000         12.7         4.70  42.2 KM           0
# 5877 0 days 03:22:39.131000         12.4         4.80  42.2 KM           0
# ...                     ...          ...          ...      ...         ...
# 6364 0 days 04:17:28.782000          9.8         6.10  42.2 KM           0
# 6365 0 days 04:30:08.835000          9.3         6.40  42.2 KM           0
# 6366 0 days 04:41:14.383000          9.0         6.65  42.2 KM           0
# 6367 0 days 04:53:55.101000          8.6         6.95  42.2 KM           0
# 6368 0 days 04:55:15.850000          8.5         6.98  42.2 KM           0
#
#       Gender_Rank_Total  Chip Time duration-min  Gun Time duration-min
# 5873                  0                  138.85                 151.29
# 5874                  0                  155.75                 170.30
# 5875                  0                  171.97                 210.18
# 5876                  0                  198.73                 211.70
# 5877                  0                  202.65                 227.94
# ...                 ...                     ...                    ...
# 6364                  0                  257.48                 269.40
# 6365                  0                  270.15                 282.23
# 6366                  0                  281.24                 293.04
# 6367                  0                  293.92                 293.92
# 6368                  0                  295.26                 295.26
#
# [101 rows x 14 columns]

# %%
marathon_with_rank_df = marathon_df[(marathon_df['Rank_Total']!=0 ) & (marathon_df['Category']=='MARATHON')].sort_values('Rank')
marathon_with_rank_df
# Out:
#       Rank  Gender Rank  Gender  Category Nationality               Gun Time  \
# 5891     1            1    Male  MARATHON          KE 0 days 02:29:30.477000
# 5892     2            2    Male  MARATHON          KE 0 days 02:32:55.041000
# 5893     3            3    Male  MARATHON          SA 0 days 02:28:56.226000
# 5894     4            4    Male  MARATHON          SA 0 days 02:31:48.639000
# 5895     5            5    Male  MARATHON          SA 0 days 02:46:59.933000
# ...    ...          ...     ...       ...         ...                    ...
# 6213   369          323    Male  MARATHON          SA 0 days 06:17:00.727000
# 6214   370          324    Male  MARATHON    Unknown! 0 days 06:17:05.542000
# 6215   371          325    Male  MARATHON          SA 0 days 06:18:22.001000
# 6216   372          326    Male  MARATHON          PK 0 days 06:20:17.131000
# 5862   373           47  Female  MARATHON          SA 0 days 06:14:05.366000
#
#                   Chip Time  Speed_Km/Hr  Pace_min_Km Distance  Rank_Total  \
# 5891 0 days 02:17:44.035000         18.3         3.25  42.2 KM         373
# 5892 0 days 02:21:08.599000         17.9         3.33  42.2 KM         373
# 5893 0 days 02:28:51.408000         17.0         3.52  42.2 KM         373
# 5894 0 days 02:31:44.038000         16.6         3.58  42.2 KM         373
# 5895 0 days 02:46:54.932000         15.1         3.95  42.2 KM         373
# ...                     ...          ...          ...      ...         ...
# 6213 0 days 06:04:25.555000          6.9         8.63  42.2 KM         373
# 6214 0 days 06:04:40.901000          6.9         8.63  42.2 KM         373
# 6215 0 days 06:05:34.724000          6.9         8.65  42.2 KM         373
# 6216 0 days 06:07:51.991000          6.8         8.72  42.2 KM         373
# 5862 0 days 06:14:05.366000          6.7         8.85  42.2 KM         373
#
#       Gender_Rank_Total  Chip Time duration-min  Gun Time duration-min
# 5891                326                  137.73                 149.51
# 5892                326                  141.14                 152.92
# 5893                326                  148.86                 148.94
# 5894                326                  151.73                 151.81
# 5895                326                  166.92                 167.00
# ...                 ...                     ...                    ...
# 6213                326                  364.43                 377.01
# 6214                326                  364.68                 377.09
# 6215                326                  365.58                 378.37
# 6216                326                  367.87                 380.29
# 5862                 47                  374.09                 374.09
#
# [373 rows x 14 columns]

# %%
# marathon_with_rank_df = marathon_df[(marathon_df['Rank_Total']!=0 ) & (marathon_df['Category']=='MARATHON')].sort_values('Rank')
# marathon_with_rank_df

# %%
# Check differences between consecutive numbers
differences = marathon_with_rank_df['Rank'].diff()
differences

# # Any difference greater than 1 indicates a gap
has_gaps = (differences > 1).any()
has_gaps
# Out:
# False

# %%
top_runner_df = marathon_df[marathon_df['Rank'].apply(lambda x: True if x in range(1, 11) else False)]
top_runner_df
# Out:
#       Rank  Gender Rank  Gender             Category Nationality  \
# 795      1            1    Male             10KM RUN          SA
# 796      2            2    Male             10KM RUN          SA
# 797      3            3    Male             10KM RUN          SO
# 798      4            4    Male             10KM RUN          SO
# 799      5            5    Male             10KM RUN          SA
# 800      6            6    Male             10KM RUN          SA
# 801      7            7    Male             10KM RUN          SA
# 802      8            8    Male             10KM RUN          KE
# 803      9            9    Male             10KM RUN          BH
# 804     10           10    Male             10KM RUN          BH
# 3443     1            1    Male          4KM FUN RUN          JO
# 3444     2            2    Male          4KM FUN RUN          SA
# 3445     3            3    Male          4KM FUN RUN          BH
# 3446     4            4    Male          4KM FUN RUN          NG
# 3447     5            5    Male          4KM FUN RUN          SA
# 3448     6            6    Male          4KM FUN RUN          SA
# 3449     7            7    Male          4KM FUN RUN          YE
# 3450     8            8    Male          4KM FUN RUN          KW
# 3451     9            9    Male          4KM FUN RUN          SA
# 3452    10           10    Male          4KM FUN RUN          SA
# 4878     1            1    Male        HALF MARATHON          MA
# 4879     2            2    Male        HALF MARATHON          SA
# 4880     3            3    Male        HALF MARATHON          BH
# 4881     4            4    Male        HALF MARATHON          UG
# 4882     5            5    Male        HALF MARATHON          SA
# 4883     6            6    Male        HALF MARATHON          ER
# 4884     7            7    Male        HALF MARATHON          SA
# 4885     8            8    Male        HALF MARATHON          EG
# 4886     9            9    Male        HALF MARATHON          GB
# 4887    10           10    Male        HALF MARATHON          SA
# 5891     1            1    Male             MARATHON          KE
# 5892     2            2    Male             MARATHON          KE
# 5893     3            3    Male             MARATHON          SA
# 5894     4            4    Male             MARATHON          SA
# 5895     5            5    Male             MARATHON          SA
# 5896     6            6    Male             MARATHON          SA
# 5897     7            7    Male             MARATHON          DZ
# 5898     8            8    Male             MARATHON          SA
# 5899     9            9    Male             MARATHON          SA
# 5900    10           10    Male             MARATHON          CN
# 6378     1            1    Male       MARATHON ELITE          ET
# 6379     2            2    Male       MARATHON ELITE          ET
# 6380     3            3    Male       MARATHON ELITE          KE
# 6381     4            4    Male       MARATHON ELITE          KE
# 6382     5            5    Male       MARATHON ELITE          KE
# 6383     6            6    Male       MARATHON ELITE          ET
# 6384     7            7    Male       MARATHON ELITE          KE
# 6385     8            8    Male       MARATHON ELITE          KE
# 6386     9            9    Male       MARATHON ELITE          KE
# 6387    10           10    Male       MARATHON ELITE          ET
# 6391     4            1  Female  HALF MARATHON ELITE          KE
# 6392     5            2  Female  HALF MARATHON ELITE          ET
# 6393     6            3  Female  HALF MARATHON ELITE          UA
# 6394     1            1    Male  HALF MARATHON ELITE          KE
# 6395     2            2    Male  HALF MARATHON ELITE          KE
# 6396     3            3    Male  HALF MARATHON ELITE          KE
#
#                    Gun Time              Chip Time  Speed_Km/Hr  Pace_min_Km  \
# 795  0 days 00:31:34.524000 0 days 00:31:33.764000         19.0         3.15
# 796  0 days 00:31:36.444000 0 days 00:31:35.168000         18.9         3.15
# 797  0 days 00:32:52.983000 0 days 00:32:52.381000         18.2         3.28
# 798  0 days 00:33:17.258000 0 days 00:33:15.920000         18.0         3.32
# 799  0 days 00:33:38.484000 0 days 00:33:36.183000         17.8         3.35
# 800  0 days 00:33:43.485000 0 days 00:33:43.485000         17.7         3.37
# 801  0 days 00:34:25.414000 0 days 00:34:24.077000         17.4         3.43
# 802  0 days 00:34:53.225000 0 days 00:34:51.268000         17.2         3.48
# 803  0 days 00:34:59.759000 0 days 00:34:58.280000         17.1         3.48
# 804  0 days 00:35:08.339000 0 days 00:35:05.442000         17.0         3.50
# 3443 0 days 00:13:18.041000 0 days 00:13:09.399000         18.2         3.28
# 3444 0 days 00:13:28.502000 0 days 00:13:20.591000         17.9         3.33
# 3445 0 days 00:13:44.113000 0 days 00:13:32.247000         17.7         3.38
# 3446 0 days 00:13:47.472000 0 days 00:13:37.804000         17.6         3.40
# 3447 0 days 00:13:52.978000 0 days 00:13:43.203000         17.4         3.42
# 3448 0 days 00:13:55.664000 0 days 00:13:45.997000         17.4         3.43
# 3449 0 days 00:13:54.714000 0 days 00:13:47.109000         17.4         3.43
# 3450 0 days 00:13:56.983000 0 days 00:13:48.363000         17.3         3.45
# 3451 0 days 00:14:21.021000 0 days 00:14:12.446000         16.8         3.55
# 3452 0 days 00:14:29.635000 0 days 00:14:19.568000         16.7         3.57
# 4878 0 days 01:14:22.379000 0 days 01:04:48.083000         19.5         3.07
# 4879 0 days 01:18:22.770000 0 days 01:08:47.996000         18.4         3.25
# 4880 0 days 01:29:06.831000 0 days 01:17:19.334000         16.3         3.65
# 4881 0 days 01:29:11.752000 0 days 01:17:21.532000         16.3         3.65
# 4882 0 days 01:30:27.009000 0 days 01:18:39.268000         16.0         3.72
# 4883 0 days 01:31:13.414000 0 days 01:19:21.573000         15.9         3.75
# 4884 0 days 01:32:13.444000 0 days 01:20:24.926000         15.7         3.80
# 4885 0 days 01:32:07.808000 0 days 01:20:38.187000         15.7         3.82
# 4886 0 days 01:33:19.446000 0 days 01:21:30.869000         15.5         3.85
# 4887 0 days 01:34:14.468000 0 days 01:22:09.867000         15.4         3.88
# 5891 0 days 02:29:30.477000 0 days 02:17:44.035000         18.3         3.25
# 5892 0 days 02:32:55.041000 0 days 02:21:08.599000         17.9         3.33
# 5893 0 days 02:28:56.226000 0 days 02:28:51.408000         17.0         3.52
# 5894 0 days 02:31:48.639000 0 days 02:31:44.038000         16.6         3.58
# 5895 0 days 02:46:59.933000 0 days 02:46:54.932000         15.1         3.95
# 5896 0 days 03:01:09.045000 0 days 02:48:32.519000         15.0         3.98
# 5897 0 days 03:01:08.946000 0 days 02:48:58.200000         14.9         4.00
# 5898 0 days 03:07:52.699000 0 days 02:55:42.253000         14.4         4.15
# 5899 0 days 03:08:42.611000 0 days 02:56:51.209000         14.3         4.18
# 5900 0 days 03:12:30.163000 0 days 02:59:59.765000         14.0         4.25
# 6378 0 days 02:06:26.790000 0 days 02:06:22.232000         20.0         2.98
# 6379 0 days 02:06:27.790000 0 days 02:06:23.132000         20.0         2.98
# 6380 0 days 02:07:34.911000 0 days 02:07:30.091000         19.8         3.02
# 6381 0 days 02:08:14.613000 0 days 02:08:09.553000         19.7         3.03
# 6382 0 days 02:08:17.152000 0 days 02:08:12.313000         19.7         3.03
# 6383 0 days 02:09:37.935000 0 days 02:09:32.124000         19.5         3.07
# 6384 0 days 02:11:09.529000 0 days 02:11:04.471000         19.3         3.10
# 6385 0 days 02:11:37.681000 0 days 02:11:32.062000         19.2         3.12
# 6386 0 days 02:17:22.739000 0 days 02:17:17.737000         18.4         3.25
# 6387 0 days 02:17:34.269000 0 days 02:17:29.088000         18.4         3.25
# 6391 0 days 01:08:55.519000 0 days 01:08:51.366000         18.3         3.25
# 6392 0 days 01:12:12.475000 0 days 01:12:08.442000         17.5         3.42
# 6393 0 days 01:18:23.645000 0 days 01:18:20.056000         16.1         3.70
# 6394 0 days 01:04:04.250000 0 days 01:04:00.497000         19.7         3.03
# 6395 0 days 01:04:06.571000 0 days 01:04:03.202000         19.7         3.03
# 6396 0 days 01:04:09.986000 0 days 01:04:06.290000         19.7         3.03
#
#      Distance  Rank_Total  Gender_Rank_Total  Chip Time duration-min  \
# 795     10 KM        2285               1524                   31.56
# 796     10 KM        2285               1524                   31.59
# 797     10 KM        2285               1524                   32.87
# 798     10 KM        2285               1524                   33.27
# 799     10 KM        2285               1524                   33.60
# 800     10 KM        2285               1524                   33.72
# 801     10 KM        2285               1524                   34.40
# 802     10 KM        2285               1524                   34.85
# 803     10 KM        2285               1524                   34.97
# 804     10 KM        2285               1524                   35.09
# 3443     4 KM        2220               1182                   13.16
# 3444     4 KM        2220               1182                   13.34
# 3445     4 KM        2220               1182                   13.54
# 3446     4 KM        2220               1182                   13.63
# 3447     4 KM        2220               1182                   13.72
# 3448     4 KM        2220               1182                   13.77
# 3449     4 KM        2220               1182                   13.79
# 3450     4 KM        2220               1182                   13.81
# 3451     4 KM        2220               1182                   14.21
# 3452     4 KM        2220               1182                   14.33
# 4878  21.1 KM        1128                908                   64.80
# 4879  21.1 KM        1128                908                   68.80
# 4880  21.1 KM        1128                908                   77.32
# 4881  21.1 KM        1128                908                   77.36
# 4882  21.1 KM        1128                908                   78.65
# 4883  21.1 KM        1128                908                   79.36
# 4884  21.1 KM        1128                908                   80.42
# 4885  21.1 KM        1128                908                   80.64
# 4886  21.1 KM        1128                908                   81.51
# 4887  21.1 KM        1128                908                   82.16
# 5891  42.2 KM         373                326                  137.73
# 5892  42.2 KM         373                326                  141.14
# 5893  42.2 KM         373                326                  148.86
# 5894  42.2 KM         373                326                  151.73
# 5895  42.2 KM         373                326                  166.92
# 5896  42.2 KM         373                326                  168.54
# 5897  42.2 KM         373                326                  168.97
# 5898  42.2 KM         373                326                  175.70
# 5899  42.2 KM         373                326                  176.85
# 5900  42.2 KM         373                326                  180.00
# 6378  42.2 KM          18                 10                  126.37
# 6379  42.2 KM          18                 10                  126.39
# 6380  42.2 KM          18                 10                  127.50
# 6381  42.2 KM          18                 10                  128.16
# 6382  42.2 KM          18                 10                  128.21
# 6383  42.2 KM          18                 10                  129.54
# 6384  42.2 KM          18                 10                  131.07
# 6385  42.2 KM          18                 10                  131.53
# 6386  42.2 KM          18                 10                  137.30
# 6387  42.2 KM          18                 10                  137.48
# 6391  21.1 KM           6                  3                   68.86
# 6392  21.1 KM           6                  3                   72.14
# 6393  21.1 KM           6                  3                   78.33
# 6394  21.1 KM           6                  3                   64.01
# 6395  21.1 KM           6                  3                   64.05
# 6396  21.1 KM           6                  3                   64.10
#
#       Gun Time duration-min
# 795                   31.58
# 796                   31.61
# 797                   32.88
# 798                   33.29
# 799                   33.64
# 800                   33.72
# 801                   34.42
# 802                   34.89
# 803                   35.00
# 804                   35.14
# 3443                  13.30
# 3444                  13.48
# 3445                  13.74
# 3446                  13.79
# 3447                  13.88
# 3448                  13.93
# 3449                  13.91
# 3450                  13.95
# 3451                  14.35
# 3452                  14.49
# 4878                  74.37
# 4879                  78.38
# 4880                  89.11
# 4881                  89.20
# 4882                  90.45
# 4883                  91.22
# 4884                  92.22
# 4885                  92.13
# 4886                  93.32
# 4887                  94.24
# 5891                 149.51
# 5892                 152.92
# 5893                 148.94
# 5894                 151.81
# 5895                 167.00
# 5896                 181.15
# 5897                 181.15
# 5898                 187.88
# 5899                 188.71
# 5900                 192.50
# 6378                 126.45
# 6379                 126.46
# 6380                 127.58
# 6381                 128.24
# 6382                 128.29
# 6383                 129.63
# 6384                 131.16
# 6385                 131.63
# 6386                 137.38
# 6387                 137.57
# 6391                  68.93
# 6392                  72.21
# 6393                  78.39
# 6394                  64.07
# 6395                  64.11
# 6396                  64.17

# %%
plt.figure(figsize=(15,8))
sns.countplot(x = 'Category', hue = 'Gender', data = top_runner_df);

# %%
#Q:2

# %%
plt.figure(figsize=(15,8))

sns.boxplot(
    marathon_df,
    y='Chip Time duration-min',
    hue="Category")
# Out:
# <Axes: ylabel='Chip Time duration-min'>

# %%
fastest_time = marathon_df.groupby('Category')['Chip Time duration-min'].min()
fastest_time
# Out:
# Category
# 10KM RUN                18.09
# 4KM FUN RUN             12.88
# HALF MARATHON           64.80
# HALF MARATHON ELITE     64.01
# MARATHON               103.18
# MARATHON ELITE         126.37
# Name: Chip Time duration-min, dtype: float64

# %%
plt.bar(fastest_time.index,
        fastest_time.values
       )
plt.grid()
plt.xticks(rotation=45)
plt.show()

# %%
#Q3

# %%
top_nat_counts_per = (top_nat_counts / marathon_df.shape[0])*100
top_nat_counts_per
# Out:
# Nationality
# SA          53.733740
# PH           7.258712
# Unknown!     4.785611
# IN           3.838124
# GB           3.372410
# EG           3.308174
# PK           2.473101
# JO           1.959210
# LB           1.927092
# MY           1.284728
# Name: count, dtype: float64

# %%
sns.barplot(y="Nationality", x="count",data=top_nat_counts_per.to_frame());
plt.grid()

# %%
(marathon_df[marathon_df["Nationality"]!= 'SA'].shape[0]/ marathon_df.shape[0])*100
# Out:
# 46.26625983619721
